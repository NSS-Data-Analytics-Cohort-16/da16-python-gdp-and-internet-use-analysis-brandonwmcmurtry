# %% [markdown]
# 3.	Import the required packages with their customary aliases as follows:
#     `import pandas as pd`
#     `import numpy as np`
#     `import matplotlib.pyplot as plt`
#     `import seaborn as sn
#
# 4.	Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column?
# 6. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.
# 7. How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?
# 9. What was the median GDP per capita value in 2020?
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.
# 11. Which country was the first to have a GDP per capita greater than $100,000?
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset. **Bonus question:** Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?
# 14. Read in the internet use dataset into a DataFrame named `internet_df`. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.
# 16. Look at the number of observations in this dataset per year. What do you notice? -
# 17. What is the first year to have a non-zero internet users percentage value?
# 18. How does the distribution of internet users percent differ for 2000 and 2014?
# 19. For how many countries was the percentage of internet users below 5% in 2014?
# 20. Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?
# 22. Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.
# 24. **Stretch Question:** Use the `qcut` function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in `gdp_per_capita_2014` into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".
# 25. **Stretch Question:** How does the median internet users percentage compare for the three gdp groups?
#
# ### Bonus exercise:
# 1.    Download another data set from the UN data (http://data.un.org/Explorer.aspx) to merge with your data and explore.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv(r'C:\Users\ymcmu\OneDrive\Documents\NSS\Python\da16-python-gdp-and-internet-use-analysis-brandonwmcmurtry\data\gdp_per_capita.csv')

# %%
gdp_df.head (5)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2023  1992.424394              NaN
# 1     Afghanistan  2022  1981.710168              NaN
# 2     Afghanistan  2021  2144.166570              NaN
# 3     Afghanistan  2020  2769.685745              NaN
# 4     Afghanistan  2019  2927.245144              NaN

# %%
gdp_df.tail (5)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8219 entries, 0 to 8218
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  8219 non-null   object
#  1   Year             8219 non-null   int64
#  2   Value            8219 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 257.0+ KB

# %%
gdp_df.describe()
# Out:
#               Year          Value  Value Footnotes
# count  8219.000000    8219.000000              0.0
# mean   2006.672345   20270.976242              NaN
# std       9.782986   22532.004246              NaN
# min    1990.000000     510.822823              NaN
# 25%    1998.000000    4284.868430              NaN
# 50%    2007.000000   11916.457927              NaN
# 75%    2015.000000   28543.305542              NaN
# max    2023.000000  174339.077325              NaN

# %%
#  Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
print(gdp_df.columns.tolist())
# Out:
# ['Country or Area', 'Year', 'Value']

# %%
gdp_df = gdp_df.rename(columns={
    "Country or Area": "Country",
    "Year": "Year",
    "Value": "GDP_Per_Capita"
})

# %%
num_years = gdp_df["Year"].nunique()
num_years
# Out:
# 34

# %%
countries_with_all_years = (
    gdp_df.groupby("Country")["Year"].nunique()
      .eq(num_years)     # True if count == num_years
)

# List of countries that have full coverage
full_coverage_countries = countries_with_all_years[countries_with_all_years].index.tolist()

full_coverage_countries
# Out:
# ['Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  "CÃ´te d'Ivoire",
#  'Dem. Rep. Congo',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD)',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data=gdp_df, x="GDP_Per_Capita", bins=30)
plt.title("Distribution of GDP per Capita")
plt.xlabel("GDP per Capita")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
gdp_df_2020 = gdp_df[gdp_df["Year"] == 2020]

plt.figure(figsize=(10,6))
sns.histplot(data=gdp_df_2020, x="GDP_Per_Capita", bins=30, kde=True)
plt.title("Distribution of GDP per Capita in 2020")
plt.xlabel("GDP per Capita")
plt.ylabel("Number of Countries")
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=gdp_df_2020, x="GDP_Per_Capita", fill=True)
plt.title("Density Plot of GDP per Capita in 2020")
plt.xlabel("GDP per Capita")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(6,8))
sns.boxplot(data=gdp_df_2020, y="GDP_Per_Capita")
plt.title("Box Plot of GDP per Capita in 2020")
plt.ylabel("GDP per Capita")
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.violinplot(data=gdp_df_2020, y="GDP_Per_Capita", inner="quartile")
plt.title("Violin Plot of GDP per Capita in 2020")
plt.ylabel("GDP per Capita")
plt.show()

# %%
median_gdp_2020 = gdp_df_2020["GDP_Per_Capita"].median()
print("Median GDP per Capita in 2020:", median_gdp_2020)
# Out:
# Median GDP per Capita in 2020: 15309.23598817024

# %%
high_gdp = gdp_df[gdp_df["GDP_Per_Capita"] > 100000]

# %%
high_gdp = high_gdp.sort_values(by="Year")

# %%
first_country = high_gdp.iloc[0]
first_country
# Out:
# Country           United Arab Emirates
# Year                              1990
# GDP_Per_Capita           108057.042464
# Name: 7827, dtype: object

# %%
df_2020 = gdp_df[gdp_df["Year"] == 2020]

# %%
highest_2020 = gdp_df_2020.loc[gdp_df_2020["GDP_Per_Capita"].idxmax()]

# %%
country_with_highest_2020 = highest_2020["Country"]
print("Country with highest GDP per capita in 2020:", country_with_highest_2020)
# Out:
# Country with highest GDP per capita in 2020: Luxembourg

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
country_df = gdp_df[gdp_df["Country"] == country_with_highest_2020]

plt.figure(figsize=(12,6))
sns.lineplot(data=country_df, x="Year", y="GDP_Per_Capita", marker="o")

plt.title(f"GDP per Capita Over Time: {country_with_highest_2020}")
plt.xlabel("Year")
plt.ylabel("GDP per Capita")
plt.grid(True)
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_2020 = gdp_df[gdp_df["Year"] == 2020]

# %%
lowest_2020 = df_2020.loc[df_2020["GDP_Per_Capita"].idxmin()]

# %%
country_with_lowest_2020 = lowest_2020["Country"]

print("Country with lowest GDP per capita in 2020:", country_with_lowest_2020)
# Out:
# Country with lowest GDP per capita in 2020: Burundi

# %%
country_low_df = gdp_df[gdp_df["Country"] == country_with_lowest_2020]

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=country_low_df, x="Year", y="GDP_Per_Capita", marker="o")

plt.title(f"GDP per Capita Over Time: {country_with_lowest_2020}")
plt.xlabel("Year")
plt.ylabel("GDP per Capita")
plt.grid(True)
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
internet_df = pd.read_csv(
    r'C:\Users\ymcmu\OneDrive\Documents\NSS\Python\da16-python-gdp-and-internet-use-analysis-brandonwmcmurtry\data\internet.csv',
    on_bad_lines='skip'
)

# %%
internet_df.head (5)
# Out:
#   Country or Area  Year  Value Value Footnotes
# 0     Afghanistan  2019  17.60               1
# 1     Afghanistan  2018  16.80               2
# 2     Afghanistan  2017  13.50               3
# 3     Afghanistan  2016  11.00               4
# 4     Afghanistan  2015   8.26               4

# %%
internet_df.tail (5)
# Out:
#      Country or Area                                               Year  \
# 6375             293  Estimated based on Survey's results. Populatio...
# 6376             294                     Preliminary. Country estimate.
# 6377             295                                 18+. ITU estimate.
# 6378             296                     ICT survey. Population age 11+
# 6379             297  Internet users aged 3 years and above who used...
#
#       Value Value Footnotes
# 6375    NaN             NaN
# 6376    NaN             NaN
# 6377    NaN             NaN
# 6378    NaN             NaN
# 6379    NaN             NaN

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
internet_df = internet_df.drop(columns=["Value Footnotes"])

# %%
internet_df = internet_df.rename(columns={
    "Country or Area": "Country",
    "Year": "Year",
    "Value": "Internet_Users_Pct"})

# %%
obs_per_year = internet_df.groupby("Year").size()

# %%
plt.figure(figsize=(20,6))
sns.barplot(x=obs_per_year.index, y=obs_per_year.values)
plt.title("Number of Internet Usage Observations per Year")
plt.xlabel("Year")
plt.ylabel("Number of Observations")
plt.xticks(rotation=45)
plt.show()

# %%
# first year non-zero

# %%
first_year_nonzero = (
    internet_df[internet_df["Internet_Users_Pct"] > 0]
    .sort_values("Year")
    .iloc[0]["Year"]
)

print(first_year_nonzero)
# Out:
# 1990

# %%
# How does the distribution of internet users percent differ for 2000 and 2014?

# %%
df_2000 = internet_df[internet_df["Year"] == 2000]

# %%
df_2014 = internet_df[internet_df["Year"] == 2014]

# %%
plt.figure(figsize=(12,6))
sns.histplot(df_2000["Internet_Users_Pct"], color="blue", label="2000", kde=True, element="step")
sns.histplot(df_2014["Internet_Users_Pct"], color="orange", label="2014", kde=True, element="step")

plt.title("Distribution of Internet Users Percentage (2000 vs 2014)")
plt.xlabel("Internet Users (%)")
plt.ylabel("Number of Countries")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
internet_df["Year"] = internet_df["Year"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 internet_df["Year"] = internet_df["Year"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
# ...

# %%
internet_df["Year"] = pd.to_numeric(internet_df["Year"], errors="coerce")

# %%
internet_df = internet_df.dropna(subset=["Year"])

# %%
internet_df["Year"] = internet_df["Year"].astype(int)

# %%
df_2000 = internet_df[internet_df["Year"] == 2000]
df_2014 = internet_df[internet_df["Year"] == 2014]

print(df_2000.info())
print(df_2014.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, 42 to 6075
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             210 non-null    object
#  1   Year                210 non-null    int32
#  2   Internet_Users_Pct  210 non-null    float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 5.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 5 to 6061
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             204 non-null    object
#  1   Year                204 non-null    int32
#  2   Internet_Users_Pct  204 non-null    float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 5.6+ KB
# None

# %%
print(df_2000.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             0 non-null      object
#  1   Year                0 non-null      object
#  2   Internet_Users_Pct  0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 0.0+ bytes
# None

# %%
internet_df.head (5)
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2019               17.60
# 1  Afghanistan  2018               16.80
# 2  Afghanistan  2017               13.50
# 3  Afghanistan  2016               11.00
# 4  Afghanistan  2015                8.26

# %%
plt.figure(figsize=(12,6))
sns.histplot(df_2000["Internet_Users_Pct"], color="blue", label="2000", kde=True, element="step")
sns.histplot(df_2014["Internet_Users_Pct"], color="orange", label="2014", kde=True, element="step")

plt.title("Distribution of Internet Users Percentage (2000 vs 2014)")
plt.xlabel("Internet Users (%)")
plt.ylabel("Number of Countries")
plt.legend()
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# For how many countries was the percentage of internet users below 5% in 2014?

# %%
low_internet_2014 = internet_df[(internet_df["Year"] == 2014) & 
                                (internet_df["Internet_Users_Pct"] < 5)]

# %%
num_countries_below_5 = low_internet_2014["Country"].nunique()

print(num_countries_below_5)
# Out:
# 10

# %%
# Merge the two data sets

# %%
gdp_and_internet_use = pd.merge(
    gdp_df,
    internet_df,
    on=["Country", "Year"],  
    how="outer"             
)

# %%
print(gdp_and_internet_use.head())
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2023     1992.424394                 NaN
# 1  Afghanistan  2022     1981.710168                 NaN
# 2  Afghanistan  2021     2144.166570                 NaN
# 3  Afghanistan  2020     2769.685745                 NaN
# 4  Afghanistan  2019     2927.245144                17.6

# %%
print(gdp_and_internet_use.tail())
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9497   Yemen  1996             NaN            0.000621
# 9498   Yemen  1990             NaN            0.000000
# 9499     141     0             NaN                 NaN
# 9500     142     0             NaN                 NaN
# 9501     159     0             NaN                 NaN

# %%
# Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid

# %%
df_2014 = internet_df[internet_df["Year"] == 2014]

# %%
top3 = df_2014.sort_values("Internet_Users_Pct", ascending=False).head(3)
top3_countries = top3["Country"].unique().tolist()

print("Top 3 countries in 2014 by Internet use %:", top3_countries)
# Out:
# Top 3 countries in 2014 by Internet use %: ['Iceland', 'Falkland (Malvinas) Islands', 'Bermuda']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
subset = gdp_and_internet_use[gdp_and_internet_use["Country"].isin(top3_countries)]

# %%
subset["Year"] = subset["Year"].astype(int)
# Out:
# C:\Users\ymcmu\AppData\Local\Temp\ipykernel_24292\2224362670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset["Year"] = subset["Year"].astype(int)

# %%
g = sns.FacetGrid(subset, col="Country", sharey=False, height=4, aspect=1.5)
g.map_dataframe(sns.lineplot, x="Year", y="GDP_Per_Capita", marker="o")

g.set_axis_labels("Year", "GDP per Capita (US$)")
g.set_titles(col_template="{col_name}")
plt.subplots_adjust(top=0.85)
g.fig.suptitle("GDP per Capita Over Time — Top 3 Internet‑Use Countries (2014)")
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
print(subset.columns)
# Out:
# Index(['Country', 'Year', 'GDP_Per_Capita', 'Internet_Users_Pct'], dtype='object')

# %%
print(subset)
print(subset.info())
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 738                       Bermuda  2023    98041.688721                 NaN
# 739                       Bermuda  2022    98057.447098                 NaN
# 740                       Bermuda  2021    92276.234605                 NaN
# 741                       Bermuda  2020    87894.401174                 NaN
# 742                       Bermuda  2019    94755.432811                 NaN
# ...                           ...   ...             ...                 ...
# 8662  Falkland (Malvinas) Islands  1997             NaN             3.76081
# 8663  Falkland (Malvinas) Islands  1995             NaN             0.00000
# 8664  Falkland (Malvinas) Islands  1994             NaN             0.00000
# 8665  Falkland (Malvinas) Islands  1993             NaN             0.00000
# 8666  Falkland (Malvinas) Islands  1990             NaN             0.00000
#
# [91 rows x 4 columns]
# ...

# %%
subset_clean = subset.dropna(subset=["GDP_Per_Capita"])

print(subset_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68 entries, 738 to 3217
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             68 non-null     object
#  1   Year                68 non-null     int32
#  2   GDP_Per_Capita      68 non-null     float64
#  3   Internet_Users_Pct  57 non-null     float64
# dtypes: float64(2), int32(1), object(1)
# memory usage: 2.4+ KB
# None

# %%
g = sns.FacetGrid(subset_clean, col="Country", sharey=False, height=4, aspect=1.5)
g.map_dataframe(sns.lineplot, x="Year", y="GDP_Per_Capita", marker="o")
g.set_axis_labels("Year", "GDP per Capita (US$)")
g.set_titles(col_template="{col_name}")
plt.subplots_adjust(top=0.85)
g.fig.suptitle("GDP per Capita Over Time — Top 3 Internet‑Use Countries (2014)")
plt.show()
# Out:
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ymcmu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2014].copy()

# %%
# Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
df_2014_clean = gdp_and_internet_use_2014.dropna(subset=["GDP_Per_Capita", "Internet_Users_Pct"])

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_2014_clean, x="GDP_Per_Capita", y="Internet_Users_Pct")

plt.title("Internet Users Percentage vs GDP per Capita (2014)")
plt.xlabel("GDP per Capita (US$)")
plt.ylabel("Internet Users (%)")
plt.xscale("log")  # optional, helps with wide range of GDP
plt.grid(True, alpha=0.3)
plt.show()

# %%
#countries with higher GDP per capita tend to have more internet usage.
